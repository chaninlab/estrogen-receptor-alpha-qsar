# %%
# Test
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_to_Dude.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-test.csv
# Out:
# Processing AUTOGEN_CHEMBL206_IC50_1 in CHEMBL206_IC50.smi (1/1299).
# Processing AUTOGEN_CHEMBL206_IC50_2 in CHEMBL206_IC50.smi (2/1299).
# Processing AUTOGEN_CHEMBL206_IC50_3 in CHEMBL206_IC50.smi (3/1299).
# Processing AUTOGEN_CHEMBL206_IC50_4 in CHEMBL206_IC50.smi (4/1299).
# Processing AUTOGEN_CHEMBL206_IC50_5 in CHEMBL206_IC50.smi (5/1299). Average speed: 2.86 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_6 in CHEMBL206_IC50.smi (6/1299). Average speed: 1.48 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_7 in CHEMBL206_IC50.smi (7/1299). Average speed: 1.10 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_8 in CHEMBL206_IC50.smi (8/1299). Average speed: 0.83 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_9 in CHEMBL206_IC50.smi (9/1299). Average speed: 0.74 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_10 in CHEMBL206_IC50.smi (10/1299). Average speed: 0.69 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_11 in CHEMBL206_IC50.smi (11/1299). Average speed: 0.62 s/mol.
# ...

# %%
# Fingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints Fingerprinter \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-Fingerprinter.csv
# Out:
# Processing AUTOGEN_CHEMBL206_IC50_1 in CHEMBL206_IC50.smi (1/1299).
# Processing AUTOGEN_CHEMBL206_IC50_2 in CHEMBL206_IC50.smi (2/1299).
# Processing AUTOGEN_CHEMBL206_IC50_3 in CHEMBL206_IC50.smi (3/1299).
# Processing AUTOGEN_CHEMBL206_IC50_4 in CHEMBL206_IC50.smi (4/1299).
# Processing AUTOGEN_CHEMBL206_IC50_5 in CHEMBL206_IC50.smi (5/1299). Average speed: 3.33 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_6 in CHEMBL206_IC50.smi (6/1299). Average speed: 1.72 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_7 in CHEMBL206_IC50.smi (7/1299). Average speed: 1.45 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_8 in CHEMBL206_IC50.smi (8/1299). Average speed: 1.10 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_9 in CHEMBL206_IC50.smi (9/1299). Average speed: 1.12 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_10 in CHEMBL206_IC50.smi (10/1299). Average speed: 0.85 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_11 in CHEMBL206_IC50.smi (11/1299). Average speed: 0.66 s/mol.
# ...

# %%
# ExtendedFingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints ExtendedFingerprinter \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-ExtendedFingerprinter.csv
# Out:
# Processing AUTOGEN_CHEMBL206_IC50_1 in CHEMBL206_IC50.smi (1/1299).
# Processing AUTOGEN_CHEMBL206_IC50_2 in CHEMBL206_IC50.smi (2/1299).
# Processing AUTOGEN_CHEMBL206_IC50_3 in CHEMBL206_IC50.smi (3/1299).
# Processing AUTOGEN_CHEMBL206_IC50_4 in CHEMBL206_IC50.smi (4/1299).
# Processing AUTOGEN_CHEMBL206_IC50_5 in CHEMBL206_IC50.smi (5/1299). Average speed: 2.80 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_6 in CHEMBL206_IC50.smi (6/1299). Average speed: 1.44 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_7 in CHEMBL206_IC50.smi (7/1299). Average speed: 1.09 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_8 in CHEMBL206_IC50.smi (8/1299). Average speed: 0.83 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_9 in CHEMBL206_IC50.smi (9/1299). Average speed: 0.72 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_10 in CHEMBL206_IC50.smi (10/1299). Average speed: 0.70 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_12 in CHEMBL206_IC50.smi (12/1299). Average speed: 0.56 s/mol.
# ...

# %%
# EStateFingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints EStateFingerprinter \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-EStateFingerprinter.csv
# Out:
# Processing AUTOGEN_CHEMBL206_IC50_1 in CHEMBL206_IC50.smi (1/1299).
# Processing AUTOGEN_CHEMBL206_IC50_2 in CHEMBL206_IC50.smi (2/1299).
# Processing AUTOGEN_CHEMBL206_IC50_3 in CHEMBL206_IC50.smi (3/1299).
# Processing AUTOGEN_CHEMBL206_IC50_4 in CHEMBL206_IC50.smi (4/1299).
# Processing AUTOGEN_CHEMBL206_IC50_5 in CHEMBL206_IC50.smi (5/1299). Average speed: 3.40 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_6 in CHEMBL206_IC50.smi (6/1299). Average speed: 1.76 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_7 in CHEMBL206_IC50.smi (7/1299). Average speed: 1.37 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_8 in CHEMBL206_IC50.smi (8/1299). Average speed: 1.37 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_9 in CHEMBL206_IC50.smi (9/1299). Average speed: 0.88 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_10 in CHEMBL206_IC50.smi (10/1299). Average speed: 0.82 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_11 in CHEMBL206_IC50.smi (11/1299). Average speed: 0.72 s/mol.
# ...

# %%
# GraphOnlyFingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints GraphOnlyFingerprinter \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-GraphOnlyFingerprinter.csv
# Out:
# Processing AUTOGEN_CHEMBL206_IC50_1 in CHEMBL206_IC50.smi (1/1299).
# Processing AUTOGEN_CHEMBL206_IC50_2 in CHEMBL206_IC50.smi (2/1299).
# Processing AUTOGEN_CHEMBL206_IC50_3 in CHEMBL206_IC50.smi (3/1299).
# Processing AUTOGEN_CHEMBL206_IC50_4 in CHEMBL206_IC50.smi (4/1299).
# Processing AUTOGEN_CHEMBL206_IC50_5 in CHEMBL206_IC50.smi (5/1299). Average speed: 3.33 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_6 in CHEMBL206_IC50.smi (6/1299). Average speed: 1.74 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_7 in CHEMBL206_IC50.smi (7/1299). Average speed: 1.26 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_8 in CHEMBL206_IC50.smi (8/1299). Average speed: 0.95 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_9 in CHEMBL206_IC50.smi (9/1299). Average speed: 0.84 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_10 in CHEMBL206_IC50.smi (10/1299). Average speed: 0.75 s/mol.
# Processing AUTOGEN_CHEMBL206_IC50_11 in CHEMBL206_IC50.smi (11/1299). Average speed: 0.67 s/mol.
# ...

# %%
# MACCSFingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints MACCSFingerprinter \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-MACCSFingerprinter.csv

# %%
# PubchemFingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints PubchemFingerprinter \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-PubchemFingerprinter.csv

# %%
# SubstructureFingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints SubStructure \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-SubStructure.csv

# %%
# SubstructureFingerprintCount
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints SubStructureCount \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-SubStructureCount.csv

# %%
# KlekotaRothFingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints SubStructure \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-KlekotaRothFingerprinter.csv

# %%
# KlekotaRothFingerprintCount
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints KlekotaRothFingerprinter \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-KlekotaRothFingerprintCount.csv

# %%
# AtomPairs2DFingerprinter
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints AtomPairs2DFingerprinter \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-AtomPairs2DFingerprinter.csv

# %%
# AtomPairs2DFingerprintCount
! java -jar -Xmx20G /Users/zeromtmu/Desktop/2017_run/PaDEL-Descriptor/PaDEL-Descriptor.jar \
-removesalt -standardizenitro -standardizetautomers -fingerprints AtomPairs2DFingerprintCount \
-dir /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50.smi \
-file  /Users/zeromtmu/Desktop/2017_run/CHEMBL206_IC50/CHEMBL206_IC50_all-Descriptors/CHEMBL206_IC50-AtomPairs2DFingerprintCount.csv
